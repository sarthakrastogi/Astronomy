# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow
image1 = imread('./content/121006.jpg')
imshow(image1);

# %%
image2 = imread('./content/121006.jpg', as_gray=True)
imshow(image2);

# %%
from skimage import filters

# prewitt kernel
pre_hor = prewitt_h(image2)
pre_ver = prewitt_v(image2)

# Sobel Kernel
ed_sobel = filters.sobel(image2)

#canny algorithm
#can = feature.canny(image2)

imshow(pre_ver, cmap='gray');

# %%
imshow(pre_hor, cmap='gray');

# %%
imshow(ed_sobel, cmap='gray');
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
from skimage.exposure import histogram
hist, hist_centers = histogram(image2)

#Plotting the Image and the Histogram of gray values
fig, axes = plt.subplots(1, 2, figsize=(8, 3))
axes[0].imshow(image2, cmap=plt.cm.gray)
axes[0].axis('off')
axes[1].plot(hist_centers, hist, lw=2)
axes[1].set_title('histogram of grey values')
# Out:
# Text(0.5, 1.0, 'histogram of grey values')

# %%
from PIL import Image

# %matplotlib inline  

#Import an image
image = Image.open("./content/121006.jpg")
im = image.convert('L')

im_array = array(im)

# %%
from pylab import *

# create a new figure
figure()
gray()
# show contours with origin upper left corner
contour(im, origin='image')
axis('equal')
axis('off')
figure()
hist(im_array.flatten(), 128)
show()
